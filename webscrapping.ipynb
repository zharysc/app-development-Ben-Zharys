# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.numbeo.com/crime/rankings_current.jsp"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# %%
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find('table', {'id': 't2'})
table
# Out:
# <table class="stripe row-border order-column compact" id="t2">
# <thead>
# <tr>
# <th><div style="font-size: 80%; vertical-align: middle;">Rank</div></th>
# <th><div style="font-size: 95%;">City</div></th>
# <th><div style="font-size: 90%;">Crime Index</div></th>
# <th><div style="font-size: 90%;">Safety Index</div></th>
# </tr>
# </thead>
# <tbody>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Pietermaritzburg">Pietermaritzburg, South Africa</a></td>
# <td style="text-align: right">82.8</td>
# <td style="text-align: right">17.2</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Pretoria">Pretoria, South Africa</a></td>
# <td style="text-align: right">81.9</td>
# <td style="text-align: right">18.1</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Caracas">Caracas, Venezuela</a></td>
# <td style="text-align: right">81.4</td>
# <td style="text-align: right">18.6</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Port-Moresby">Port Moresby, Papua New Guinea</a></td>
# <td style="text-align: right">81.3</td>
# <td style="text-align: right">18.7</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Johannesburg">Johannesburg, South Africa</a></td>
# <td style="text-align: right">80.9</td>
# <td style="text-align: right">19.1</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Durban">Durban, South Africa</a></td>
# <td style="text-align: right">80.4</td>
# <td style="text-align: right">19.6</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/San-Pedro-Sula">San Pedro Sula, Honduras</a></td>
# <td style="text-align: right">79.4</td>
# <td style="text-align: right">20.6</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Memphis">Memphis, TN, United States</a></td>
# <td style="text-align: right">78.6</td>
# <td style="text-align: right">21.4</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Port-Elizabeth">Port Elizabeth, South Africa</a></td>
# <td style="text-align: right">78.5</td>
# <td style="text-align: right">21.5</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Salvador">Salvador, Brazil</a></td>
# <td style="text-align: right">76.5</td>
# <td style="text-align: right">23.5</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Port-Of-Spain">Port of Spain, Trinidad And Tobago</a></td>
# <td style="text-align: right">76.4</td>
# <td style="text-align: right">23.6</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Fortaleza">Fortaleza, Brazil</a></td>
# <td style="text-align: right">75.9</td>
# <td style="text-align: right">24.1</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Rio-De-Janeiro">Rio de Janeiro, Brazil</a></td>
# <td style="text-align: right">75.2</td>
# <td style="text-align: right">24.8</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Recife">Recife, Brazil</a></td>
# <td style="text-align: right">74.8</td>
# <td style="text-align: right">25.2</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Guayaquil">Guayaquil, Ecuador</a></td>
# <td style="text-align: right">74.4</td>
# <td style="text-align: right">25.6</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Cape-Town">Cape Town, South Africa</a></td>
# <td style="text-align: right">73.7</td>
# <td style="text-align: right">26.3</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Detroit">Detroit, MI, United States</a></td>
# <td style="text-align: right">72.8</td>
# <td style="text-align: right">27.2</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Baltimore">Baltimore, MD, United States</a></td>
# <td style="text-align: right">72.1</td>
# <td style="text-align: right">27.9</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Cali">Cali, Colombia</a></td>
# <td style="text-align: right">72.0</td>
# <td style="text-align: right">28.0</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Tijuana">Tijuana, Mexico</a></td>
# <td style="text-align: right">71.5</td>
# <td style="text-align: right">28.5</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Albuquerque">Albuquerque, NM, United States</a></td>
# <td style="text-align: right">71.0</td>
# <td style="text-align: right">29.0</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Porto-Alegre">Porto Alegre, Brazil</a></td>
# <td style="text-align: right">70.7</td>
# <td style="text-align: right">29.3</td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/
td>
# </tr>
# <tr style="width: 100%">
# <td></td>
# <td class="cityOrCountryInIndicesTable"><a class="discreet_link" href="https://www.numbeo.com/crime/in/Abu-Dhabi">Abu Dhabi, United Arab Emirates</a></td>
# <td style="text-align: right">11.0</td>
# <td style="text-align: right">89.0</td>
# </tr>
# </tbody>
# </table>

# %%
headers = [th.text.strip() for th in table.find_all('th')]
headers
# Out:
# ['Rank', 'City', 'Crime Index', 'Safety Index']

# %%
# Extract rows
rows = []
for tr in table.find_all('tr')[1:]:  # skip header row
    cells = [td.text.strip() for td in tr.find_all('td')]
    if cells:
        rows.append(cells)

rows
# Out:
# [['', 'Pietermaritzburg, South Africa', '82.8', '17.2'],
#  ['', 'Pretoria, South Africa', '81.9', '18.1'],
#  ['', 'Caracas, Venezuela', '81.4', '18.6'],
#  ['', 'Port Moresby, Papua New Guinea', '81.3', '18.7'],
#  ['', 'Johannesburg, South Africa', '80.9', '19.1'],
#  ['', 'Durban, South Africa', '80.4', '19.6'],
#  ['', 'San Pedro Sula, Honduras', '79.4', '20.6'],
#  ['', 'Memphis, TN, United States', '78.6', '21.4'],
#  ['', 'Port Elizabeth, South Africa', '78.5', '21.5'],
#  ['', 'Salvador, Brazil', '76.5', '23.5'],
#  ['', 'Port of Spain, Trinidad And Tobago', '76.4', '23.6'],
#  ['', 'Fortaleza, Brazil', '75.9', '24.1'],
#  ['', 'Rio de Janeiro, Brazil', '75.2', '24.8'],
#  ['', 'Recife, Brazil', '74.8', '25.2'],
#  ['', 'Guayaquil, Ecuador', '74.4', '25.6'],
#  ['', 'Cape Town, South Africa', '73.7', '26.3'],
#  ['', 'Detroit, MI, United States', '72.8', '27.2'],
#  ['', 'Baltimore, MD, United States', '72.1', '27.9'],
#  ['', 'Cali, Colombia', '72.0', '28.0'],
#  ['', 'Tijuana, Mexico', '71.5', '28.5'],
#  ['', 'Albuquerque, NM, United States', '71.0', '29.0'],
#  ['', 'Porto Alegre, Brazil', '70.7', '29.3'],
#  ['', 'Lima, Peru', '70.2', '29.8'],
#  ['', 'Saint Louis, MO, United States', '70.0', '30.0'],
#  ['', 'Sao Paulo, Brazil', '70.0', '30.0'],
#  ['', 'Kingston, Jamaica', '69.1', '30.9'],
#  ['', 'Oakland, CA, United States', '68.9', '31.1'],
#  ['', 'Lagos, Nigeria', '68.8', '31.2'],
#  ['', 'Marseille, France', '68.3', '31.7'],
#  ['', 'Damascus, Syria', '68.2', '31.8'],
#  ['', 'Windhoek, Namibia', '67.6', '32.4'],
#  ['', 'New Orleans, LA, United States', '67.1', '32.9'],
#  ['', 'San Juan, Puerto Rico', '67.1', '32.9'],
#  ['', 'Santo Domingo, Dominican Republic', '67.0', '33.0'],
#  ['', 'Alice Springs, Australia', '66.9', '33.1'],
#  ['', 'Mexico City, Mexico', '66.7', '33.3'],
#  ['', 'Bogota, Colombia', '66.7', '33.3'],
#  ['', 'Rockhampton, Australia', '66.3', '33.7'],
#  ['', 'Milwaukee, WI, United States', '66.2', '33.8'],
#  ['', 'Campinas, Brazil', '65.8', '34.2'],
#  ['', 'Nimes, France', '65.6', '34.4'],
#  ['', 'Chicago, IL, United States', '65.5', '34.5'],
#  ['', 'Philadelphia, PA, United States', '65.3', '34.7'],
#  ['', 'Manila, Philippines', '64.6', '35.4'],
#  ['', 'Surrey, Canada', '64.4', '35.6'],
#  ['', 'Quezon City, Philippines', '64.3', '35.7'],
#  ['', 'Atlanta, GA, United States', '64.3', '35.7'],
#  ['', 'Santiago, Chile', '64.2', '35.8'],
#  ['', 'Quito, Ecuador', '63.6', '36.4'],
#  ['', 'Houston, TX, United States', '63.2', '36.8'],
#  ['', 'Birmingham, United Kingdom', '63.1', '36.9'],
#  ['', 'Lethbridge, AB, Canada', '63.1', '36.9'],
#  ['', 'Buenos Aires, Argentina', '63.0', '37.0'],
#  ['', 'Darwin, Australia', '62.9', '37.1'],
#  ['', 'Grenoble, France', '62.6', '37.4'],
#  ['', 'Guadalajara, Mexico', '62.4', '37.6'],
#  ['', 'Sudbury, Canada', '62.3', '37.7'],
#  ['', 'Kelowna, Canada', '62.2', '37.8'],
#  ['', 'Dhaka, Bangladesh', '62.2', '37.8'],
#  ['', 'Naples, Italy', '62.1', '37.9'],
#  ['', 'Cairns, Australia', '61.9', '38.1'],
#  ['', 'Townsville, Australia', '61.4', '38.6'],
#  ['', 'Winnipeg, Canada', '60.8', '39.2'],
#  ['', 'Harare, Zimbabwe', '60.7', '39.3'],
#  ['', 'San Francisco, CA, United States', '60.6', '39.4'],
#  ['', 'Cordoba, Argentina', '60.6', '39.4'],
#  ['', 'Curitiba, Brazil', '60.5', '39.5'],
#  ['', 'Brantford, Canada', '60.5', '39.5'],
#  ['', 'Indianapolis, IN, United States', '60.3', '39.7'],
#  ['', 'Sault Ste. Marie, Canada', '60.3', '39.7'],
#  ['', 'Oshawa, Canada', '60.2', '39.8'],
#  ['', 'Lyon, France', '60.0', '40.0'],
#  ['', 'Montpellier, France', '60.0', '40.0'],
#  ['', 'Washington, DC, United States', '59.8', '40.2'],
#  ['', 'Belo Horizonte, Brazil', '59.6', '40.4'],
#  ['', 'Nairobi, Kenya', '59.4', '40.6'],
#  ['', 'Nice, France', '59.2', '40.8'],
#  ['', 'Kuala Lumpur, Malaysia', '59.1', '40.9'],
#  ['', 'Delhi, India', '59.1', '40.9'],
#  ['', 'Brasilia, Brazil', '58.7', '41.3'],
#  ['', 'Portland, OR, United States', '58.6', '41.4'],
#  ['', 'Kansas City, MO, United States', '58.6', '41.4'],
#  ['', 'Nantes, France', '58.4', '41.6'],
#  ['', 'Ghaziabad, India', '58.4', '41.6'],
#  ['', 'Bradford, United Kingdom', '58.2', '41.8'],
#  ['', 'Puebla, Mexico', '58.1', '41.9'],
#  ['', 'Paris, France', '58.0', '42.0'],
#  ['', 'Liege, Belgium', '57.9', '42.1'],
#  ['', 'Karachi, Pakistan', '57.5', '42.5'],
#  ['', 'Tehran, Iran', '57.3', '42.7'],
#  ['', 'Coventry, United Kingdom', '57.2', '42.8'],
#  ['', 'Montevideo, Uruguay', '56.5', '43.5'],
#  ['', 'Hamilton, Canada', '56.3', '43.7'],
#  ['', 'Brussels, Belgium', '56.1', '43.9'],
#  ['', 'Asuncion, Paraguay', '56.1', '43.9'],
#  ['', 'Manchester, United Kingdom', '55.9', '44.1'],
#  ['', 'San Salvador, El Salvador', '55.7', '44.3'],
#  ['', 'Lille, France', '55.7', '44.3'],
#  ['', 'Minneapolis, MN, United States', '55.6', '44.4'],
#  ['', 'Hamilton, New Zealand', '55.6', '44.4'],
#  ['', 'San Jose, Costa Rica', '55.6', '44.4'],
#  ['', 'London, United Kingdom', '55.6', '44.4'],
#  ['', 'Brampton, Canada', '55.5', '44.5'],
#  ['', 'Las Vegas, NV, United States', '55.5', '44.5'],
#  ['', 'Odessa (Odesa), Ukraine', '55.5', '44.5'],
#  ['', 'Seattle, WA, United States', '55.3', '44.7'],
#  ['', 'Athens, Greece', '55.2', '44.8'],
#  ['', 'Casablanca, Morocco', '55.2', '44.8'],
#  ['', 'Noida, India', '55.1', '44.9'],
#  ['', 'Malmo, Sweden', '55.1', '44.9'],
#  ['', 'Ballarat, Australia', '55.1', '44.9'],
#  ['', 'Cancun, Mexico', '54.8', '45.2'],
#  ['', 'Klang, Malaysia', '54.8', '45.2'],
#  ['', 'Jacksonville, FL, United States', '54.8', '45.2'],
#  ['', 'Kamloops, Canada', '54.8', '45.2'],
#  ['', 'Tucson, AZ, United States', '54.7', '45.3'],
#  ['', 'Amadora, Portugal', '54.4', '45.6'],
#  ['', 'Baghdad, Iraq', '54.2', '45.8'],
#  ['', 'Dublin, Ireland', '54.1', '45.9'],
#  ['', 'Los Angeles, CA, United States', '54.1', '45.9'],
#  ['', 'Bangalore, India', '54.0', '46.0'],
#  ['', 'Gurgaon, India', '54.0', '46.0'],
#  ['', 'London, Canada', '53.8', '46.2'],
#  ['', 'Dnipro, Ukraine', '53.7', '46.3'],
#  ['', 'Medellin, Colombia', '53.7', '46.3'],
#  ['', 'Milan, Italy', '53.5', '46.5'],
#  ['', 'Regina, Canada', '53.5', '46.5'],
#  ['', 'Nanaimo, BC, Canada', '53.5', '46.5'],
#  ['', 'Miami, FL, United States', '53.3', '46.7'],
#  ['', 'Toulouse, France', '53.2', '46.8'],
#  ['', 'Almaty, Kazakhstan', '53.1', '46.9'],
#  ['', 'Jakarta, Indonesia', '52.8', '47.2'],
#  ['', 'Phoenix, AZ, United States', '52.8', '47.2'],
#  ['', 'Nottingham, United Kingdom', '52.7', '47.3'],
#  ['', 'Barcelona, Spain', '52.1', '47.9'],
#  ['', 'Thessaloniki, Greece', '52.1', '47.9'],
#  ['', 'Turin, Italy', '51.9', '48.1'],
#  ['', 'Dallas, TX, United States', '51.7', '48.3'],
#  ['', 'Rawalpindi, Pakistan', '51.6', '48.4'],
#  ['', 'Ulaanbaatar, Mongolia', '51.5', '48.5'],
#  ['', 'New York, NY, United States', '51.1', '48.9'],
#  ['', 'Algiers, Algeria', '51.0', '49.0'],
#  ['', 'Bali, Indonesia', '51.0', '49.0'],
#  ['', 'Drogheda, Ireland', '50.6', '49.4'],
#  ['', 'Phnom Penh, Cambodia', '50.6', '49.4'],
#  ['', 'Auckland, New Zealand', '50.5', '49.5'],
#  ['', 'Cebu, Philippines', '50.4', '49.6'],
#  ['', 'Ho Chi Minh City, Vietnam', '50.4', '49.6'],
#  ['', 'San Miguel de Allende, Mexico', '50.0', '50.0'],
#  ['', 'Cairo, Egypt', '50.0', '50.0'],
#  ['', 'Bari, Italy', '49.9', '50.1'],
#  ['', 'Minsk, Belarus', '49.9', '50.1'],
#  ['', 'Saskatoon, Canada', '49.9', '50.1'],
#  ['', 'Bordeaux, France', '49.8', '50.2'],
#  ['', 'Addis Ababa, Ethiopia', '49.7', '50.3'],
#  ['', 'Moncton, Canada', '49.5', '50.5'],
#  ['', 'Bilbao, Spain', '49.4', '50.6'],
#  ['', 'Sacramento, CA, United States', '49.2', '50.8'],
#  ['', 'Columbus, OH, United States', '49.2', '50.8'],
#  ['', 'Charlotte, NC, United States', '49.2', '50.8'],
#  ['', 'Bologna, Italy', '48.8', '51.2'],
#  ['', 'Johor Bahru, Malaysia', '48.6', '51.4'],
#  ['', 'Liverpool, United Kingdom', '48.5', '51.5'],
#  ['', 'Tunis, Tunisia', '48.5', '51.5'],
#  ['', 'Catania, Italy', '48.5', '51.5'],
#  ['', 'Indore, India', '48.2', '51.8'],
#  ['', 'Monterrey, Mexico', '48.1', '51.9'],
#  ['', 'Nashville, TN, United States', '48.1', '51.9'],
#  ['', 'Istanbul, Turkey', '48.1', '51.9'],
#  ['', 'Raleigh, NC, United States', '48.0', '52.0'],
#  ['', 'Orlando, FL, United States', '48.0', '52.0'],
#  ['', 'San Jose, CA, United States', '48.0', '52.0'],
#  ['', 'Belfast, United Kingdom', '48.0', '52.0'],
#  ['', 'Denver, CO, United States', '48.0', '52.0'],
#  ['', 'Newcastle, Australia', '47.8', '52.2'],
#  ['', 'Honolulu, HI, United States', '47.7', '52.3'],
#  ['', 'Rome, Italy', '47.4', '52.6'],
#  ['', 'St.Catharines, Canada', '47.3', '52.7'],
#  ['', 'Kharkiv, Ukraine', '47.2', '52.8'],
#  ['', 'Bremen, Germany', '47.2', '52.8'],
#  ['', 'Panama City, Panama', '47.1', '52.9'],
#  ['', 'Gold Coast, Australia', '47.0', '53.0'],
#  ['', 'Kolkata, India', '46.9', '53.1'],
#  ['', 'Beirut, Lebanon', '46.8', '53.2'],
#  ['', 'Edmonton, Canada', '46.8', '53.2'],
#  ['', 'Stockholm, Sweden', '46.5', '53.5'],
#  ['', 'Windsor, Canada', '46.5', '53.5'],
#  ['', 'Florianopolis, Brazil', '46.4', '53.6'],
#  ['', 'Palermo, Italy', '46.2', '53.8'],
#  ['', 'Skopje, North Macedonia', '46.1', '53.9'],
#  ['', 'San Antonio, TX, United States', '46.0', '54.0'],
#  ['', 'Cuenca, Ecuador', '45.9', '54.1'],
#  ['', 'Pattaya, Thailand', '45.9', '54.1'],
#  ['', 'Gothenburg, Sweden', '45.8', '54.2'],
#  ['', 'Novosibirsk, Russia', '45.5', '54.5'],
#  ['', 'Kiev (Kyiv), Ukraine', '45.5', '54.5'],
#  ['', 'Lucknow (Lakhnau), India', '45.5', '54.5'],
#  ['', 'Leeds, United Kingdom', '45.1', '54.9'],
#  ['', 'Glasgow, United Kingdom', '45.1', '54.9'],
#  ['', 'Hanover, Germany', '45.1', '54.9'],
#  ['', 'Brooklyn, NY, United States', '45.0', '55.0'],
#  ['', 'Genoa, Italy', '44.9', '55.1'],
#  ['', 'Alexandria, Egypt', '44.8', '55.2'],
#  ['', 'Constanta, Romania', '44.8', '55.2'],
#  ['', 'Sarajevo, Bosnia And Herzegovina', '44.8', '55.2'],
#  ['', 'Christchurch, New Zealand', '44.7', '55.3'],
#  ['', 'Kristiansand, Norway', '44.6', '55.4'],
#  ['', 'Austin, TX, United States', '44.5', '55.5'],
#  ['', 'Cologne, Germany', '44.5', '55.5'],
#  ['', 'Frankfurt, Germany', '44.5', '55.5'],
#  ['', 'Berlin, Germany', '44.5', '55.5'],
#  ['', 'Tampa, FL, United States', '44.5', '55.5'],
#  ['', 'Melbourne, Australia', '44.2', '55.8'],
#  ['', 'Mumbai, India', '44.1', '55.9'],
#  ['', 'Mississauga, Canada', '44.0', '56.0'],
#  ['', 'Limerick, Ireland', '43.6', '56.4'],
#  ['', 'Toronto, Canada', '43.6', '56.4'],
#  ['', 'Yekaterinburg, Russia', '43.0', '57.0'],
#  ['', 'Bristol, United Kingdom', '43.0', '57.0'],
#  ['', 'Kitchener, Canada', '42.9', '57.1'],
#  ['', 'Sheffield, United Kingdom', '42.9', '57.1'],
#  ['', 'Vaughan, Canada', '42.8', '57.2'],
#  ['', 'Vancouver, Canada', '42.7', '57.3'],
#  ['', 'Colombo, Sri Lanka', '42.6', '57.4'],
#  ['', 'Hyderabad, India', '42.6', '57.4'],
#  ['', 'Chandigarh, India', '42.4', '57.6'],
#  ['', 'Florence, Italy', '42.1', '57.9'],
#  ['', 'Perth, Australia', '42.0', '58.0'],
#  ['', 'Chisinau, Moldova', '41.9', '58.1'],
#  ['', 'Leipzig, Germany', '41.9', '58.1'],
#  ['', 'Pune, India', '41.3', '58.7'],
#  ['', 'Strasbourg, France', '40.8', '59.2'],
#  ['', 'Tirana, Albania', '40.2', '59.8'],
#  ['', 'Chennai, India', '40.0', '60.0'],
#  ['', 'Antwerp, Belgium', '39.9', '60.1'],
#  ['', 'Iloilo, Philippines', '39.9', '60.1'],
#  ['', 'Hamburg, Germany', '39.8', '60.2'],
#  ['', 'Cardiff, United Kingdom', '39.7', '60.3'],
#  ['', 'Boston, MA, United States', '39.7', '60.3'],
#  ['', 'Victoria, Canada', '39.6', '60.4'],
#  ['', 'Ankara, Turkey', '39.5', '60.5'],
#  ['', 'Newcastle upon Tyne, United Kingdom', '39.5', '60.5'],
#  ['', 'San Diego, CA, United States', '39.4', '60.6'],
#  ['', 'Bonn, Germany', '39.2', '60.8'],
#  ['', 'Halifax, Canada', '39.2', '60.8'],
#  ['', 'Limassol, Cyprus', '39.1', '60.9'],
#  ['', 'Thiruvananthapuram, India', '39.0', '61.0'],
#  ['', 'Brighton, United Kingdom', '38.9', '61.1'],
#  ['', 'Novi Sad, Serbia', '38.8', '61.2'],
#  ['', 'Sofia, Bulgaria', '38.8', '61.2'],
#  ['', 'Pittsburgh, PA, United States', '38.6', '61.4'],
#  ['', 'Bangkok, Thailand', '38.2', '61.8'],
#  ['', 'Kingston, Canada', '38.2', '61.8'],
#  ['', 'Brisbane, Australia', '38.2', '61.8'],
#  ['', 'Makati, Philippines', '38.1', '61.9'],
#  ['', 'Calgary, Canada', '37.9', '62.1'],
#  ['', 'Belgrade, Serbia', '37.9', '62.1'],
#  ['', 'Lodz, Poland', '37.8', '62.2'],
#  ['', 'Queretaro (Santiago de Querétaro), Mexico', '37.8', '62.2'],
#  ['', 'Saint Petersburg, Russia', '37.6', '62.4'],
#  ['', 'Riga, Latvia', '37.6', '62.4'],
#  ['', 'Amman, Jordan', '37.4', '62.6'],
#  ['', 'Boise, ID, United States', '37.4', '62.6'],
#  ['', 'Madison, WI, United States', '37.4', '62.6'],
#  ['', 'Lviv, Ukraine', '37.2', '62.8'],
#  ['', 'Cork, Ireland', '36.9', '63.1'],
#  ['', 'Lahore, Pakistan', '36.9', '63.1'],
#  ['', 'Kaunas, Lithuania', '36.7', '63.3'],
#  ['', 'Kathmandu, Nepal', '36.7', '63.3'],
#  ['', 'Aberdeen, United Kingdom', '36.7', '63.3'],
#  ['', 'Seville (Sevilla), Spain', '36.5', '63.5'],
#  ['', 'Navi Mumbai, India', '36.5', '63.5'],
#  ['', 'Karlsruhe, Germany', '36.5', '63.5'],
#  ['', 'Cagliari, Italy', '36.3', '63.7'],
#  ['', 'Jerusalem, Israel', '36.1', '63.9'],
#  ['', 'Palma de Mallorca, Spain', '36.0', '64.0'],
#  ['', 'Salt Lake City, UT, United States', '35.9', '64.1'],
#  ['', 'Moscow, Russia', '35.2', '64.8'],
#  ['', 'Alicante, Spain', '34.7', '65.3'],
#  ['', 'Jaipur, India', '34.7', '65.3'],
#  ['', 'Valencia, Spain', '34.7', '65.3'],
#  ['', 'Havana, Cuba', '34.5', '65.5'],
#  ['', 'Varna, Bulgaria', '34.4', '65.6'],
#  ['', 'Iasi, Romania', '34.4', '65.6'],
#  ['', 'Oslo, Norway', '34.3', '65.7'],
#  ['', 'Puerto Vallarta, Mexico', '33.9', '66.1'],
#  ['', 'Sydney, Australia', '33.9', '66.1'],
#  ['', 'Budapest, Hungary', '33.9', '66.1'],
#  ['', 'Irvine, CA, United States', '33.9', '66.1'],
#  ['', 'Hanoi, Vietnam', '33.8', '66.2'],
#  ['', 'Wellington, New Zealand', '33.6', '66.4'],
#  ['', 'Hobart, Australia', '33.5', '66.5'],
#  ['', 'Surat, India', '33.4', '66.6'],
#  ['', 'Rabat, Morocco', '33.2', '66.8'],
#  ['', 'Porto, Portugal', '33.2', '66.8'],
#  ['', 'Izmir, Turkey', '33.2', '66.8'],
#  ['', 'Astana (Nur-Sultan), Kazakhstan', '33.2', '66.8'],
#  ['', 'Guelph, Canada', '33.1', '66.9'],
#  ['', 'Adelaide, Australia', '33.0', '67.0'],
#  ['', 'Osaka, Japan', '33.0', '67.0'],
#  ['', 'Montreal, Canada', '32.8', '67.2'],
#  ['', 'Nicosia, Cyprus', '32.7', '67.3'],
#  ['', 'Lisbon, Portugal', '32.6', '67.4'],
#  ['', 'Dusseldorf, Germany', '32.5', '67.5'],
#  ['', 'Freiburg im Breisgau, Germany', '32.3', '67.7'],
#  ['', 'Lund, Sweden', '32.1', '67.9'],
#  ['', 'Ahmedabad, India', '31.5', '68.5'],
#  ['', 'Islamabad, Pakistan', '31.4', '68.6'],
#  ['', 'Gdansk, Poland', '31.3', '68.7'],
#  ['', 'Basel, Switzerland', '31.2', '68.8'],
#  ['', 'Malaga, Spain', '31.0', '69.0'],
#  ['', 'Galway, Ireland', '30.7', '69.3'],
#  ['', 'San Sebastian, Spain', '30.5', '69.5'],
#  ['', 'Bratislava, Slovakia', '30.5', '69.5'],
#  ['', 'Vadodara, India', '30.3', '69.7'],
#  ['', 'Edinburgh, United Kingdom', '30.2', '69.8'],
#  ['', 'Baku, Azerbaijan', '30.1', '69.9'],
#  ['', 'Vilnius, Lithuania', '30.1', '69.9'],
#  ['', 'Split, Croatia', '30.1', '69.9'],
#  ['', 'Ottawa, Canada', '29.9', '70.1'],
#  ['', 'Nuremberg, Germany', '29.8', '70.2'],
#  ['', 'Dresden, Germany', '29.7', '70.3'],
#  ['', 'Stuttgart, Germany', '29.5', '70.5'],
#  ['', 'Geneva, Switzerland', '29.4', '70.6'],
#  ['', 'Antalya, Turkey', '29.3', '70.7'],
#  ['', 'Kuwait City, Kuwait', '28.8', '71.2'],
#  ['', 'Guangzhou, China', '28.8', '71.2'],
#  ['', 'Madrid, Spain', '28.8', '71.2'],
#  ['', 'Bursa, Turkey', '28.7', '71.3'],
#  ['', 'Burlington, Canada', '28.7', '71.3'],
#  ['', 'Davao, Philippines', '28.6', '71.4'],
#  ['', 'Bucharest, Romania', '28.5', '71.5'],
#  ['', 'Penang, Malaysia', '28.3', '71.7'],
#  ['', 'Vienna, Austria', '28.2', '71.8'],
#  ['', 'Lausanne, Switzerland', '28.1', '71.9'],
#  ['', 'Nizhny Novgorod, Russia', '27.8', '72.2'],
#  ['', 'Luxembourg, Luxembourg', '27.8', '72.2'],
#  ['', 'Poznan, Poland', '27.8', '72.2'],
#  ['', 'Canberra, Australia', '27.7', '72.3'],
#  ['', 'Trieste, Italy', '27.6', '72.4'],
#  ['', 'Graz, Austria', '27.2', '72.8'],
#  ['', 'Shanghai, China', '26.5', '73.5'],
#  ['', 'Rotterdam, Netherlands', '26.0', '74.0'],
#  ['', 'Tel Aviv-Yafo, Israel', '25.9', '74.1'],
#  ['', 'Copenhagen, Denmark', '25.8', '74.2'],
#  ['', 'Tashkent, Uzbekistan', '25.8', '74.2'],
#  ['', 'Oakville, Canada', '25.7', '74.3'],
#  ['', 'Bern, Switzerland', '25.7', '74.3'],
#  ['', 'Mangalore, India', '25.6', '74.4'],
#  ['', 'Amsterdam, Netherlands', '25.6', '74.4'],
#  ['', 'Timisoara, Romania', '25.5', '74.5'],
#  ['', 'Brasov, Romania', '25.5', '74.5'],
#  ['', 'Warsaw, Poland', '25.4', '74.6'],
#  ['', 'Tbilisi, Georgia', '25.4', '74.6'],
#  ['', 'Helsinki, Finland', '25.3', '74.7'],
#  ['', 'Wroclaw, Poland', '25.1', '74.9'],
#  ['', 'Beijing, China', '25.1', '74.9'],
#  ['', 'Tokyo, Japan', '25.1', '74.9'],
#  ['', 'Jeddah (Jiddah), Saudi Arabia', '25.0', '75.0'],
#  ['', 'Shenzhen, China', '24.9', '75.1'],
#  ['', 'Zaragoza (Saragossa), Spain', '24.9', '75.1'],
#  ['', 'Eskisehir, Turkey', '24.9', '75.1'],
#  ['', 'Krakow (Cracow), Poland', '24.8', '75.2'],
#  ['', 'Seoul, South Korea', '24.7', '75.3'],
#  ['', 'Brno, Czech Republic', '24.6', '75.4'],
#  ['', 'Prague, Czech Republic', '24.6', '75.4'],
#  ['', 'Riyadh, Saudi Arabia', '24.6', '75.4'],
#  ['', 'Gent, Belgium', '24.0', '76.0'],
#  ['', 'Stavanger, Norway', '23.9', '76.1'],
#  ['', 'Bergen, Norway', '23.8', '76.2'],
#  ['', 'Reykjavik, Iceland', '23.6', '76.4'],
#  ['', 'Merida, Mexico', '23.6', '76.4'],
#  ['', 'Rijeka, Croatia', '23.5', '76.5'],
#  ['', 'Zurich, Switzerland', '23.5', '76.5'],
#  ['', 'Singapore, Singapore', '22.5', '77.5'],
#  ['', 'Quebec City, Canada', '22.4', '77.6'],
#  ['', 'Cluj-Napoca, Romania', '22.4', '77.6'],
#  ['', 'Chiang Mai, Thailand', '22.1', '77.9'],
#  ['', 'Yerevan, Armenia', '21.9', '78.1'],
#  ['', 'Ljubljana, Slovenia', '21.8', '78.2'],
#  ['', 'Tallinn, Estonia', '21.7', '78.3'],
#  ['', 'Lugano, Switzerland', '21.6', '78.4'],
#  ['', 'Tartu, Estonia', '21.4', '78.6'],
#  ['', 'Hong Kong, Hong Kong (China)', '21.4', '78.6'],
#  ['', 'Zagreb, Croatia', '21.4', '78.6'],
#  ['', 'Groningen, Netherlands', '21.4', '78.6'],
#  ['', 'Trondheim, Norway', '21.1', '78.9'],
#  ['', 'Utrecht, Netherlands', '21.0', '79.0'],
#  ['', 'Munich, Germany', '21.0', '79.0'],
#  ['', 'Tampere, Finland', '20.6', '79.4'],
#  ['', 'Eindhoven, Netherlands', '20.5', '79.5'],
#  ['', 'The Hague (Den Haag), Netherlands', '19.9', '80.1'],
#  ['', 'Muscat, Oman', '18.7', '81.3'],
#  ['', 'Craiova, Romania', '17.4', '82.6'],
#  ['', 'Taipei, Taiwan', '16.5', '83.5'],
#  ['', 'Ras al-Khaimah, United Arab Emirates', '16.1', '83.9'],
#  ['', 'Dubai, United Arab Emirates', '16.1', '83.9'],
#  ['', 'Sharjah, United Arab Emirates', '15.6', '84.4'],
#  ['', 'Doha, Qatar', '15.5', '84.5'],
#  ['', 'Ajman, United Arab Emirates', '13.5', '86.5'],
#  ['', 'Abu Dhabi, United Arab Emirates', '11.0', '89.0']]

# %%
# Convert to DataFrame
df = pd.DataFrame(rows, columns=headers)
df.head()
# Out:
#   Rank                            City Crime Index Safety Index
# 0       Pietermaritzburg, South Africa        82.8         17.2
# 1               Pretoria, South Africa        81.9         18.1
# 2                   Caracas, Venezuela        81.4         18.6
# 3       Port Moresby, Papua New Guinea        81.3         18.7
# 4           Johannesburg, South Africa        80.9         19.1

# %% [markdown]
# # Preprocessing scrapped data
# ## Adding Country and continent

# %%
# Extracting Country
df['Country'] = df['City'].apply(lambda x: x.split(',')[-1].strip())

# %%
# Determining continent
# !pip install pycountry_convert
import pycountry_convert as pc

def country_to_continent(country_name):
    try:
        country_code = pc.country_name_to_country_alpha2(country_name)
        continent_code = pc.country_alpha2_to_continent_code(country_code)
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except:
        return 'Unknown'

df['Continent'] = df['Country'].apply(country_to_continent)
# Out:
# Collecting pycountry_convert
#   Downloading pycountry_convert-0.7.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting pprintpp>=0.3.0 (from pycountry_convert)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting pycountry>=16.11.27.1 (from pycountry_convert)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting pytest>=3.4.0 (from pycountry_convert)
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-mock>=1.6.3 (from pycountry_convert)
#   Downloading pytest_mock-3.15.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytest-cov>=2.5.1 (from pycountry_convert)
#   Downloading pytest_cov-7.0.0-py3-none-any.whl.metadata (31 kB)
# Collecting repoze.lru>=0.7 (from pycountry_convert)
#   Downloading repoze.lru-0.7-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\zhary\anaconda3\envs\geo\lib\site-packages (from pycountry_convert) (0.45.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\zhary\anaconda3\envs\geo\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.4.6)
# Collecting iniconfig>=1.0.1 (from pytest>=3.4.0->pycountry_convert)
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in c:\users\zhary\anaconda3\envs\geo\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (25.0)
# Collecting pluggy<2,>=1.5 (from pytest>=3.4.0->pycountry_convert)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\zhary\anaconda3\envs\geo\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (2.19.2)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=2.5.1->pycountry_convert)
#   Downloading coverage-7.13.0-cp311-cp311-win_amd64.whl.metadata (8.7 kB)
# Downloading pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 48.6 MB/s  0:00:00
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Downloading pytest_cov-7.0.0-py3-none-any.whl (22 kB)
# Downloading coverage-7.13.0-cp311-cp311-win_amd64.whl (221 kB)
# Downloading pytest_mock-3.15.1-py3-none-any.whl (10 kB)
# Downloading repoze.lru-0.7-py3-none-any.whl (10 kB)
# Installing collected packages: repoze.lru, pprintpp, pycountry, pluggy, iniconfig, coverage, pytest, pytest-mock, pytest-cov, pycountry_convert
#
#    -------- -------------------------------  2/10 [pycountry]
#    -------- -------------------------------  2/10 [pycountry]
#    -------- -------------------------------  2/10 [pycountry]
#    -------- -------------------------------  2/10 [pycountry]
#    ---------------- -----------------------  4/10 [iniconfig]
#    -------------------- -------------------  5/10 [coverage]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ------------------------ ---------------  6/10 [pytest]
#    ---------------------------------------- 10/10 [pycountry_convert]
#
# Successfully installed coverage-7.13.0 iniconfig-2.3.0 pluggy-1.6.0 pprintpp-0.4.0 pycountry-24.6.1 pycountry_convert-0.7.2 pytest-9.0.2 pytest-cov-7.0.0 pytest-mock-3.15.1 repoze.lru-0.7

# %%
df.head()
# Out:
#   Rank                            City Crime Index Safety Index  \
# 0       Pietermaritzburg, South Africa        82.8         17.2
# 1               Pretoria, South Africa        81.9         18.1
# 2                   Caracas, Venezuela        81.4         18.6
# 3       Port Moresby, Papua New Guinea        81.3         18.7
# 4           Johannesburg, South Africa        80.9         19.1
#
#             Country      Continent
# 0      South Africa         Africa
# 1      South Africa         Africa
# 2         Venezuela  South America
# 3  Papua New Guinea        Oceania
# 4      South Africa         Africa

# %%
def crime_index_countries(continent = None, num_countries = 10, ascending = False):
    """ 
    This function returns a DataFrame of countries with their Crime Index and Continent.
    It can filter by continent and limit the number of countries returned.

    Parameters:
    continent (str): The continent to filter by (e.g., 'Europe', 'Asia'). If None, no filtering is applied.
    num_countries (int): The number of countries to return.
    ascending (bool): Whether to sort the Crime Index in ascending order.

    Returns:
    pd.DataFrame: A DataFrame with columns 'Country', 'Crime Index', and 'Continent'.
    """

    # === Scrapping from the web page ===============================================
    url = "https://www.numbeo.com/crime/rankings_current.jsp"
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }
    
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    table = soup.find('table', {'id': 't2'})
    headers = [th.text.strip() for th in table.find_all('th')]

    rows = []
    for tr in table.find_all('tr')[1:]:  # skip header row
        cells = [td.text.strip() for td in tr.find_all('td')]
        if cells:
            rows.append(cells)

    # === Converting to DataFrame ===================================================
    df = pd.DataFrame(rows, columns=headers)
    df['Country'] = df['City'].apply(lambda x: x.split(',')[-1].strip())

    # === Determining continent =====================================================
    df['Continent'] = df['Country'].apply(country_to_continent)

    # === Filtering and sorting =====================================================
    if continent:
        df = df[df['Continent'] == continent]
    df['Crime Index'] = pd.to_numeric(df['Crime Index'], errors='coerce')
    df = df.sort_values(by='Crime Index', ascending=ascending).head(num_countries)   
    
    return df[['City', 'Crime Index']]

# %%
## Example usage:
result_df = crime_index_countries(continent='Europe', num_countries=5, ascending=True)
print(result_df)
# Out:
#                                   City  Crime Index
# 394                   Craiova, Romania         17.4
# 392  The Hague (Den Haag), Netherlands         19.9
# 391             Eindhoven, Netherlands         20.5
# 390                   Tampere, Finland         20.6
# 389                    Munich, Germany         21.0
